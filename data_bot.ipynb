# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from os import path

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler, Normalizer

from sklearn import metrics
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('bot/bot.csv')
df
# Out:
# C:\Users\ashuk\AppData\Local\Temp\ipykernel_24536\1975148587.py:1: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('bot/bot.csv')
#          pkSeqID         stime flgs  flgs_number proto  proto_number  \
# 0              1  1.528089e+09    e            1   tcp             1
# 1              2  1.528089e+09    e            1   arp             2
# 2              3  1.528089e+09    e            1   tcp             1
# 3              4  1.528089e+09    e            1   tcp             1
# 4              5  1.528089e+09    e            1   tcp             1
# ...          ...           ...  ...          ...   ...           ...
# 3668517  3668518  1.529381e+09    e            1   tcp             1
# 3668518  3668519  1.529381e+09    e            1   tcp             1
# 3668519  3668520  1.529381e+09    e            1   tcp             1
# 3668520  3668521  1.529381e+09    e            1   tcp             1
# 3668521  3668522  1.529381e+09    e            1   arp             2
#
#                    saddr  sport            daddr dport  ...  \
# 0        192.168.100.147  49960    192.168.100.7    80  ...
# 1          192.168.100.7     -1  192.168.100.147    -1  ...
# 2        192.168.100.147  49962    192.168.100.7    80  ...
# 3        192.168.100.147  49964    192.168.100.7    80  ...
# 4        192.168.100.147  49966    192.168.100.7    80  ...
# ...                  ...    ...              ...   ...  ...
# 3668517  192.168.100.150  35064    192.168.100.3    22  ...
# 3668518  192.168.100.150  35066    192.168.100.3    22  ...
# 3668519  192.168.100.150  35070    192.168.100.3    22  ...
# 3668520    192.168.100.3  43001  192.168.100.150  4433  ...
# 3668521    192.168.100.3     -1  192.168.100.149    -1  ...
#
#          AR_P_Proto_P_DstIP  N_IN_Conn_P_DstIP N_IN_Conn_P_SrcIP  \
# 0                  1.127040                 96                75
# 1              15267.200000                  1                 2
# 2                  1.127040                 96                75
# 3                  1.127040                 96                75
# 4                  1.127040                 96                75
# ...                     ...                ...               ...
# 3668517            9.889330                 19                19
# 3668518            9.889330                 19                19
# 3668519            9.889330                 19                19
# 3668520       666667.000000                  1                 3
# 3668521            0.018868                  2                 3
#
#          AR_P_Proto_P_Sport  AR_P_Proto_P_Dport  \
# 0                  1.133720            1.129970
# 1                  0.005142            0.005142
# 2                  1.135100            1.129970
# 3                  1.135140            1.129970
# 4                  1.135260            1.129970
# ...                     ...                 ...
# 3668517          455.754000            9.889330
# 3668518        10453.000000            9.889330
# 3668519           10.785200            9.889330
# 3668520       666667.000000        22346.400000
# 3668521            0.018868            0.018868
#
#          Pkts_P_State_P_Protocol_P_DestIP  Pkts_P_State_P_Protocol_P_SrcIP  \
# 0                                     770                              602
# 1                                       2                                6
# 2                                     770                              602
# 3                                     770                              602
# 4                                     770                              602
# ...                                   ...                              ...
# 3668517                                30                               30
# 3668518                                30                               30
# 3668519                               441                              441
# 3668520                                 2                                4
# 3668521                                16                               16
#
#          attack  category  subcategory
# 0             1       DoS         HTTP
# 1             1       DoS         HTTP
# 2             1       DoS         HTTP
# 3             1       DoS         HTTP
# 4             1       DoS         HTTP
# ...         ...       ...          ...
# 3668517       1     Theft   Keylogging
# 3668518       1     Theft   Keylogging
# 3668519       1     Theft   Keylogging
# 3668520       1     Theft   Keylogging
# 3668521       1     Theft   Keylogging
#
# [3668522 rows x 46 columns]

# %%
# Replace inf with NaN
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# Drop rows with NaN values
df.dropna(inplace=True)

# %%
df['Label'] = df['category'] +" " +df['subcategory']
df.drop(['attack', 'category' ,'subcategory','saddr','daddr','sport','dport'], axis=1,inplace=True)
df
# Out:
#          pkSeqID         stime flgs  flgs_number proto  proto_number  pkts  \
# 0              1  1.528089e+09    e            1   tcp             1     8
# 1              2  1.528089e+09    e            1   arp             2     2
# 2              3  1.528089e+09    e            1   tcp             1     8
# 3              4  1.528089e+09    e            1   tcp             1     8
# 4              5  1.528089e+09    e            1   tcp             1     8
# ...          ...           ...  ...          ...   ...           ...   ...
# 3668517  3668518  1.529381e+09    e            1   tcp             1     6
# 3668518  3668519  1.529381e+09    e            1   tcp             1     6
# 3668519  3668520  1.529381e+09    e            1   tcp             1    31
# 3668520  3668521  1.529381e+09    e            1   tcp             1     2
# 3668521  3668522  1.529381e+09    e            1   arp             2    16
#
#          bytes state  state_number  ...  TnP_Per_Dport  AR_P_Proto_P_SrcIP  \
# 0         1980   RST             1  ...            772            1.142970
# 1          120   CON             2  ...              8            0.003857
# 2         2126   RST             1  ...            772            1.142970
# 3         2024   RST             1  ...            772            1.142970
# 4         2319   RST             1  ...            772            1.142970
# ...        ...   ...           ...  ...            ...                 ...
# 3668517    434   RST             1  ...            471            9.889330
# 3668518    434   RST             1  ...            471            9.889330
# 3668519   5472   FIN             6  ...            471            9.889330
# 3668520    134   RST             1  ...              4        22346.400000
# 3668521    960   CON             2  ...             16            0.018868
#
#          AR_P_Proto_P_DstIP  N_IN_Conn_P_DstIP  N_IN_Conn_P_SrcIP  \
# 0                  1.127040                 96                 75
# 1              15267.200000                  1                  2
# 2                  1.127040                 96                 75
# 3                  1.127040                 96                 75
# 4                  1.127040                 96                 75
# ...                     ...                ...                ...
# 3668517            9.889330                 19                 19
# 3668518            9.889330                 19                 19
# 3668519            9.889330                 19                 19
# 3668520       666667.000000                  1                  3
# 3668521            0.018868                  2                  3
#
#          AR_P_Proto_P_Sport  AR_P_Proto_P_Dport  \
# 0                  1.133720            1.129970
# 1                  0.005142            0.005142
# 2                  1.135100            1.129970
# 3                  1.135140            1.129970
# 4                  1.135260            1.129970
# ...                     ...                 ...
# 3668517          455.754000            9.889330
# 3668518        10453.000000            9.889330
# 3668519           10.785200            9.889330
# 3668520       666667.000000        22346.400000
# 3668521            0.018868            0.018868
#
#          Pkts_P_State_P_Protocol_P_DestIP  Pkts_P_State_P_Protocol_P_SrcIP  \
# 0                                     770                              602
# 1                                       2                                6
# 2                                     770                              602
# 3                                     770                              602
# 4                                     770                              602
# ...                                   ...                              ...
# 3668517                                30                               30
# 3668518                                30                               30
# 3668519                               441                              441
# 3668520                                 2                                4
# 3668521                                16                               16
#
#                     Label
# 0                DoS HTTP
# 1                DoS HTTP
# 2                DoS HTTP
# 3                DoS HTTP
# 4                DoS HTTP
# ...                   ...
# 3668517  Theft Keylogging
# 3668518  Theft Keylogging
# 3668519  Theft Keylogging
# 3668520  Theft Keylogging
# 3668521  Theft Keylogging
#
# [3668522 rows x 40 columns]

# %%
# import matplotlib.pyplot as plt

# # Assuming cicidsdf is your DataFrame
# label_counts = df.Label.value_counts()

# # Create a list of labels based on the unique values in 'Label' column
# labels = ['BENIGN', 'DDoS', 'PortScan', 'Botnet', 'Infiltration', 'WebAttack', 'BruteForce', 'DoS']

# plt.figure(figsize=(8,8))
# plt.pie(label_counts, labels=labels[:len(label_counts)], autopct='%0.4f%%')
# labels = [f'{l}, {s:0.4f}%' for l, s in zip(labels, (label_counts/df.shape[0])*100)]
# plt.legend(bbox_to_anchor=(0.85, 1), loc='upper left', labels=labels)
# plt.savefig('plots/Pie_chart_binary.png', bbox_inches='tight')  # bbox_inches='tight' ensures the legend is not cut off
# plt.show()

# %%
le = LabelEncoder()

df['Label'] = le.fit_transform(df['Label'])

encoded_labels = {num:label for (num, label) in zip(range(15), le.classes_)}

encoded_labels
# Out:
# {0: 'DDoS HTTP',
#  1: 'DDoS TCP',
#  2: 'DDoS UDP',
#  3: 'DoS HTTP',
#  4: 'DoS TCP',
#  5: 'DoS UDP',
#  6: 'Normal Normal',
#  7: 'Reconnaissance OS_Fingerprint',
#  8: 'Reconnaissance Service_Scan',
#  9: 'Theft Data_Exfiltration',
#  10: 'Theft Keylogging'}

# %%
le = LabelEncoder()

df['proto'] = le.fit_transform(df['proto'])

encoded_labels = {num:label for (num, label) in zip(range(15), le.classes_)}

encoded_labels
# Out:
# {0: 'arp', 1: 'icmp', 2: 'ipv6-icmp', 3: 'tcp', 4: 'udp'}

# %%
le = LabelEncoder()

df['state'] = le.fit_transform(df['state'])

encoded_labels = {num:label for (num, label) in zip(range(15), le.classes_)}

encoded_labels
# Out:
# {0: 'ACC',
#  1: 'CON',
#  2: 'ECO',
#  3: 'FIN',
#  4: 'INT',
#  5: 'MAS',
#  6: 'NRS',
#  7: 'REQ',
#  8: 'RST',
#  9: 'TST',
#  10: 'URP'}

# %%
le = LabelEncoder()

df['flgs'] = le.fit_transform(df['flgs'])

encoded_labels = {num:label for (num, label) in zip(range(15), le.classes_)}

encoded_labels
# Out:
# {0: 'e',
#  1: 'e   t',
#  2: 'e  D',
#  3: 'e &',
#  4: 'e *',
#  5: 'e d',
#  6: 'e g',
#  7: 'e s',
#  8: 'eU'}

# %%
# Separate features and labels
X = df.drop(columns=['Label'])
y = df['Label']

# Split the data
x_train, x_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42, stratify=y
)
X
# Out:
#          pkSeqID         stime  flgs  flgs_number  proto  proto_number  pkts  \
# 0              1  1.528089e+09     0            1      3             1     8
# 1              2  1.528089e+09     0            1      0             2     2
# 2              3  1.528089e+09     0            1      3             1     8
# 3              4  1.528089e+09     0            1      3             1     8
# 4              5  1.528089e+09     0            1      3             1     8
# ...          ...           ...   ...          ...    ...           ...   ...
# 3668517  3668518  1.529381e+09     0            1      3             1     6
# 3668518  3668519  1.529381e+09     0            1      3             1     6
# 3668519  3668520  1.529381e+09     0            1      3             1    31
# 3668520  3668521  1.529381e+09     0            1      3             1     2
# 3668521  3668522  1.529381e+09     0            1      0             2    16
#
#          bytes  state  state_number  ...  TnP_PerProto  TnP_Per_Dport  \
# 0         1980      8             1  ...           772            772
# 1          120      1             2  ...             8              8
# 2         2126      8             1  ...           772            772
# 3         2024      8             1  ...           772            772
# 4         2319      8             1  ...           772            772
# ...        ...    ...           ...  ...           ...            ...
# 3668517    434      8             1  ...           475            471
# 3668518    434      8             1  ...           475            471
# 3668519   5472      3             6  ...           475            471
# 3668520    134      8             1  ...           475              4
# 3668521    960      1             2  ...            16             16
#
#          AR_P_Proto_P_SrcIP  AR_P_Proto_P_DstIP  N_IN_Conn_P_DstIP  \
# 0                  1.142970            1.127040                 96
# 1                  0.003857        15267.200000                  1
# 2                  1.142970            1.127040                 96
# 3                  1.142970            1.127040                 96
# 4                  1.142970            1.127040                 96
# ...                     ...                 ...                ...
# 3668517            9.889330            9.889330                 19
# 3668518            9.889330            9.889330                 19
# 3668519            9.889330            9.889330                 19
# 3668520        22346.400000       666667.000000                  1
# 3668521            0.018868            0.018868                  2
#
#          N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  AR_P_Proto_P_Dport  \
# 0                       75            1.133720            1.129970
# 1                        2            0.005142            0.005142
# 2                       75            1.135100            1.129970
# 3                       75            1.135140            1.129970
# 4                       75            1.135260            1.129970
# ...                    ...                 ...                 ...
# 3668517                 19          455.754000            9.889330
# 3668518                 19        10453.000000            9.889330
# 3668519                 19           10.785200            9.889330
# 3668520                  3       666667.000000        22346.400000
# 3668521                  3            0.018868            0.018868
#
#          Pkts_P_State_P_Protocol_P_DestIP  Pkts_P_State_P_Protocol_P_SrcIP
# 0                                     770                              602
# 1                                       2                                6
# 2                                     770                              602
# 3                                     770                              602
# 4                                     770                              602
# ...                                   ...                              ...
# 3668517                                30                               30
# 3668518                                30                               30
# 3668519                               441                              441
# 3668520                                 2                                4
# 3668521                                16                               16
#
# [3668522 rows x 39 columns]

# %%
ss = StandardScaler().fit(x_train)
x_train = ss.transform(x_train)
x_test = ss.transform(x_test)

# %%
from sklearn.decomposition import PCA

pca = PCA(.99).fit(x_train)

x_train = pca.transform(x_train)
x_test = pca.transform(x_test)

# %%
norm = Normalizer().fit(x_train)

x_train = norm.transform(x_train)
x_test = norm.transform(x_test)

# %%
y_train = y_train.values.reshape(-1,1)
y_test = y_test.values.reshape(-1,1)

# %%
np.save("data/botnet/x_train.npy", x_train)
np.save("data/botnet/y_train.npy", y_train)
np.save("data/botnet/x_test.npy", x_test)
np.save("data/botnet/y_test.npy", y_test)

# %%
y_train.shape
# Out:
# (2751391, 1)

# %%
x_train.shape
# Out:
# (2751391, 25)
